# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\misc\heart_attack\indian-liver-patient-records\liver_patient_processed.csv")

# %%
corr=df.corr()
plt.subplots(figsize=(10,9))
heatmap=sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True)

# %%
corr
# Out:
#                                  Age    Gender  Total_Bilirubin  \
# Age                         1.000000  0.056560         0.011763
# Gender                      0.056560  1.000000         0.089291
# Total_Bilirubin             0.011763  0.089291         1.000000
# Direct_Bilirubin            0.007529  0.100436         0.874618
# Alkaline_Phosphotase        0.065952  0.018240         0.250361
# Alamine_Aminotransferase   -0.086612  0.163617         0.304003
# Aspartate_Aminotransferase -0.039678  0.182142         0.389796
# Total_Protiens             -0.191581 -0.095942        -0.011916
# Albumin                    -0.265924 -0.093799        -0.222250
# Albumin_and_Globulin_Ratio -0.227517 -0.011903        -0.244524
# Dataset                    -0.137351 -0.082416        -0.220208
#
#                             Direct_Bilirubin  Alkaline_Phosphotase  \
# Age                                 0.007529              0.065952
# ...

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df,hue='Dataset')
plt.show()

# %%
sns.swarmplot(x='Dataset',y='Direct_Bilirubin',hue='Dataset',data=df)

# %%
## 1==not patient, 2==patient
