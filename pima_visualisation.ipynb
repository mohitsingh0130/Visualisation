# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"D:\misc\heart_attack\pima-indians-diabetes-database\processedpima3.csv")

# %%
corr=df.corr()
plt.subplots(figsize=(10,9))
heatmap=sns.heatmap(corr,xticklabels=corr.columns,yticklabels=corr.columns,annot=True)

# %%
corr
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.120723       0.212204       0.028047
# Glucose                      0.120723  1.000000       0.202690       0.118727
# BloodPressure                0.212204  0.202690       1.000000       0.137429
# SkinThickness                0.028047  0.118727       0.137429       1.000000
# Insulin                     -0.018082  0.354111       0.011538       0.239485
# BMI                          0.042696  0.196654       0.264509       0.551297
# DiabetesPedigreeFunction    -0.028542  0.103864       0.000731       0.132091
# Age                          0.589502  0.246475       0.342313       0.052121
# Outcome                      0.221898  0.406354       0.161919       0.180456
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.018082  0.042696                 -0.028542
# ...

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df,hue='Outcome')
plt.show()
# Out:
# E:\anaconda\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# E:\anaconda\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
sns.swarmplot(x='Outcome',y='Age',hue='Outcome',data=df)

# %%
sns.swarmplot(x='Outcome',y='DiabetesPedigreeFunction',hue='Outcome',data=df)
